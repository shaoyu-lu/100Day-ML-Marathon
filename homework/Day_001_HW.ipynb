# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    return sum((y - y_hat)**2) / len(y)

def mean_absolute_error(y, y_hat):
    return sum(abs(y - y_hat)) / len(y)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 210.346
# The Mean absolute error is 11.753

# %% [markdown]
# ***

# %% [markdown]
# ### 作業 1
#
# [Kaggle Competitions: Chinese QA](https://www.kaggle.com/c/ml-2017fall-final-chinese-qa/data)
#
# * 此項目為中文問答資料集。問答系統現在被廣泛使用，舉凡金融業的客服、粉專問答機器人都是應用之一，能減少人力支出。從前簡單的對答大多能交付rule-base系統，直到現在深度學習、RNN和seq2seq模型的問世，機器能模仿更複雜的語言行為、回答更難的問題。然而，深度學習也面臨一困境——訓練往往需要上萬筆資料——尤其目前繁中的資料更是少見，因此這份資料集相當符合訓練的需求。
#
#
# * 此份問答集由台達電子公司(Delta)提供。訓練集、測試集共有4904篇文章，共16352對問答。文章皆引用自維基百科內容，經過去除連結、括號、備註符號等處理並改寫後，成為通順的文章段落。每個文章有數對問答，皆是針對段落提問，並能從文章中的字句得到的答案，以json檔的形式儲存。
#
#
# * 評估方式使用了F1-score，因為答案皆來自文章，將「猜測的答案」與「正確答案」作如下運算：
#
# $$precision = \frac {\mid words_{hit} \mid} {\mid words_{guess} \mid} ,\quad
# recall =\frac {\mid words_{hit} \mid} {\mid words_{answer} \mid}$$
# $$F1 = 2 * \frac {precision * recall} {precision + recall}$$
#
# F1-score可以評估模型的表現是否穩健。
# [單純只計算presion, recall 或是accuracy的問題](https://blog.csdn.net/aws3217150/article/details/50479457)
#   _From Day1.pdf_

# %% [markdown]
# ### 作業 2
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# #### 1. 核心問題 (tips：如何定義 「提升業績 & 你的假設」)
# 會使用載客服務的動機，大約有幾項：
# - 有一定經濟能力與要求乘載品質的乘客（醫生教授）
# - 節省時間（趕路、在車上要處理別的事）
# - 公共交通不易到達（山上海邊）
# - 路線不熟（觀光客）
#
# 目前知名的載客服務有台灣大車隊、uber等等，我想很重要的幾點有：
# - 叫車方便快速，兩者的司機數量夠多，車隊的電話好記(55688)、都能使用app叫車，不用雙方確認老半天
# - 資訊透明，乘客可以快速掌握車輛動向，並確認路線與到達時間
# - 收費合理，使用app付費節省付款時間
# - 品質穩定，受過訓練的司機，品行端正等等
# - 優惠多，與多家廠商合作，經常釋放利多有助於吸引新客戶加入
#
# 他們都結合了司機與乘客的app來做到這點，並且在一定品質的服務體驗後，能將客人留住
#
#
#
# #### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# >車體裝設GPS，追蹤車輛動向
# >司機與乘客都有管理app，可以觀載客情形：
#
# 乘客：出發地與目的地、使用的時間點、每次花費、乘客的個人資訊（性別、年齡）、每次服務體驗的評價
# 司機：路線、時速、單位時間內（時、日、月）的載客量與高低峰、熱門與冷門的載客點與目的地、整體評價
# 其他：天候、節日、景點、大型活動、施工路段
#
# #### 3. 蒐集而來的資料型態為何
#
# #### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
